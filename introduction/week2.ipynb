# %% [markdown]
# # CAPSTONE
# ## Battle of the Neighborhoods
# ### __Italian Restaurants__
# khaled Amayri
#
# ### -------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### __Introduction__
# This final project explores the best locations for Italian restaurants throughout the city of New York. Food Business News stated that worldwide pasta sales were up for the second year in a row with the United Sates holding the largest market (Donley, 2018).  New York is a major metropolitan area with more than 8.4 million (Quick Facts, 2018) people living within city limits. Most of the Italian immigration into the United States occurred during the late 19th and early 20th century with over two million immigrants between 1900 and 1910.  Italian families first settled in Little Italy’s neighborhood around Mulberry Street as has continued to thrive ever since.  With almost 700,000 Manhattan inhabitants reporting Italian ancestry, the need to find and enjoy Italian cuisine is on the rise.  This report explores which neighborhoods and boroughs of New York City have the most as well as the best Italian restaurants. Additionally, I will attempt to answer the questions “Where should I open an Italian Restaurant?” and “Where should I stay If I want great Italian food?”

# %% [markdown]
# ### __Data__
# In order to answer the above questions, data on New York City neighborhoods, boroughs to include boundaries, latitude, longitude, restaurants, and restaurant ratings and tips are required.
#
# New York City data containing the neighborhoods and boroughs, latitudes, and longitudes will be obtained from the data source: https://cocl.us/new_york_dataset
#
# New York City data containing neighborhood boundaries will be obtained from the data source: https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm
#
# All data related to locations and quality of Italian restaurants will be obtained via the FourSquare API utilized via the Request library in Python.

# %% [markdown]
# ### __Methodology__
# •	Data will be collected from https://cocl.us/new_york_dataset and cleaned and processed into a dataframe.
#
# •	FourSquare be used to locate all venues and then filtered by Italian restaurants.  Ratings, tips, and likes by users will be counted and added to the dataframe.
#
# •	Data will be sorted based on rankings
#
# •	Finally, the data be will be visually assessed using graphing from various Python libraries.

# %% [markdown]
# ### __Problem Statement__
# 1.	What is / are the best location(s) for Italian cuisine in New York City?
# 2.	In what Neighborhood and/or borough should I open an Italian restaurant to have the best chance of being successful?
# 3.	Where would I go in New York City to have the best Italian food?

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline
import seaborn as sns

print('Done!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-3.3.0               |           py36_0         747 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          3.3.0-py36_0      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.10.16-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.9.11-py36_0              --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# altair-3.3.0         | 747 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          91 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Done!

# %%
CLIENT_ID = 'XT2LYHMKNVQFG411HHP20TPXY5FJEJDOGTUAD0WISPOK1NT0' # your Foursquare ID
CLIENT_SECRET = 'I2IUISK5VU3XMTF0GQ3IGMKAKX5SA2JIB1AZPN5GAULGV0CI' # your Foursquare Secret
VERSION = '20180604'

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude


def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    return new_york_data
ny_data = get_new_york_data()
ny_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
clr = "orange"
ny_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Neighborhoods per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. Neighborhoods',fontsize = 15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
# queens has most neighborhoods
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name']
italian_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in ny_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    italian_resturants=venues[venues['Category']=='Italian Restaurant']   
    print('(',count,'/',len(ny_data),')','Italian Resturants in '+Neighborhood+', '+Borough+':'+str(len(italian_resturants)))
    print(row)
    for resturant_detail in italian_resturants.values.tolist():
        id, name , category=resturant_detail
        italian_rest_ny = italian_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Italian Resturants in Wakefield, Bronx:0
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 2 / 306 ) Italian Resturants in Co-op City, Bronx:0
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 3 / 306 ) Italian Resturants in Eastchester, Bronx:0
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 4 / 306 ) Italian Resturants in Fieldston, Bronx:0
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 5 / 306 ) Italian Resturants in Riverdale, Bronx:0
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 6 / 306 ) Italian Resturants in Kingsbridge, Bronx:0
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 7 / 306 ) Italian Resturants in Marble Hill, Manhattan:0
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 8 / 306 ) Italian Resturants in Woodlawn, Bronx:1
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 9 / 306 ) Italian Resturants in Norwood, Bronx:0
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 10 / 306 ) Italian Resturants in Williamsbridge, Bronx:0
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 11 / 306 ) Italian Resturants in Baychester, Bronx:0
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 12 / 306 ) Italian Resturants in Pelham Parkway, Bronx:2
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 13 / 306 ) Italian Resturants in City Island, Bronx:1
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 14 / 306 ) Italian Resturants in Bedford Park, Bronx:0
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 15 / 306 ) Italian Resturants in University Heights, Bronx:0
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 16 / 306 ) Italian Resturants in Morris Heights, Bronx:0
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 17 / 306 ) Italian Resturants in Fordham, Bronx:0
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 18 / 306 ) Italian Resturants in East Tremont, Bronx:0
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 19 / 306 ) Italian Resturants in West Farms, Bronx:0
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 20 / 306 ) Italian Resturants in High  Bridge, Bronx:0
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 21 / 306 ) Italian Resturants in Melrose, Bronx:0
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 22 / 306 ) Italian Resturants in Mott Haven, Bronx:0
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 23 / 306 ) Italian Resturants in Port Morris, Bronx:0
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 24 / 306 ) Italian Resturants in Longwood, Bronx:0
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 25 / 306 ) Italian Resturants in Hunts Point, Bronx:0
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 26 / 306 ) Italian Resturants in Morrisania, Bronx:0
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 27 / 306 ) Italian Resturants in Soundview, Bronx:0
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 28 / 306 ) Italian Resturants in Clason Point, Bronx:0
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 29 / 306 ) Italian Resturants in Throgs Neck, Bronx:0
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 30 / 306 ) Italian Resturants in Country Club, Bronx:0
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 31 / 306 ) Italian Resturants in Parkchester, Bronx:0
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 32 / 306 ) Italian Resturants in Westchester Square, Bronx:0
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 33 / 306 ) Italian Resturants in Van Nest, Bronx:0
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 34 / 306 ) Italian Resturants in Morris Park, Bronx:1
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 35 / 306 ) Italian Resturants in Belmont, Bronx:17
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 36 / 306 ) Italian Resturants in Spuyten Duyvil, Bronx:0
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 37 / 306 ) Italian Resturants in North Riverdale, Bronx:1
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 38 / 306 ) Italian Resturants in Pelham Bay, Bronx:2
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 39 / 306 ) Italian Resturants in Schuylerville, Bronx:0
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 40 / 306 ) Italian Resturants in Edgewater Park, Bronx:1
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 41 / 306 ) Italian Resturants in Castle Hill, Bronx:0
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 42 / 306 ) Italian Resturants in Olinville, Bronx:0
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 43 / 306 ) Italian Resturants in Pelham Gardens, Bronx:1
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 44 / 306 ) Italian Resturants in Concourse, Bronx:1
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 45 / 306 ) Italian Resturants in Unionport, Bronx:0
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 46 / 306 ) Italian Resturants in Edenwald, Bronx:0
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 47 / 306 ) Italian Resturants in Bay Ridge, Brooklyn:6
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 48 / 306 ) Italian Resturants in Bensonhurst, Brooklyn:2
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 49 / 306 ) Italian Resturants in Sunset Park, Brooklyn:1
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 50 / 306 ) Italian Resturants in Greenpoint, Brooklyn:1
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 51 / 306 ) Italian Resturants in Gravesend, Brooklyn:1
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 52 / 306 ) Italian Resturants in Brighton Beach, Brooklyn:0
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 53 / 306 ) Italian Resturants in Sheepshead Bay, Brooklyn:0
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 54 / 306 ) Italian Resturants in Manhattan Terrace, Brooklyn:0
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 55 / 306 ) Italian Resturants in Flatbush, Brooklyn:0
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 56 / 306 ) Italian Resturants in Crown Heights, Brooklyn:0
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 57 / 306 ) Italian Resturants in East Flatbush, Brooklyn:0
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 58 / 306 ) Italian Resturants in Kensington, Brooklyn:0
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 59 / 306 ) Italian Resturants in Windsor Terrace, Brooklyn:0
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 60 / 306 ) Italian Resturants in Prospect Heights, Brooklyn:0
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 61 / 306 ) Italian Resturants in Brownsville, Brooklyn:0
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 62 / 306 ) Italian Resturants in Williamsburg, Brooklyn:0
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 63 / 306 ) Italian Resturants in Bushwick, Brooklyn:1
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 64 / 306 ) Italian Resturants in Bedford Stuyvesant, Brooklyn:0
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 65 / 306 ) Italian Resturants in Brooklyn Heights, Brooklyn:0
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 66 / 306 ) Italian Resturants in Cobble Hill, Brooklyn:3
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 67 / 306 ) Italian Resturants in Carroll Gardens, Brooklyn:8
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 68 / 306 ) Italian Resturants in Red Hook, Brooklyn:0
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 69 / 306 ) Italian Resturants in Gowanus, Brooklyn:0
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 70 / 306 ) Italian Resturants in Fort Greene, Brooklyn:4
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 71 / 306 ) Italian Resturants in Park Slope, Brooklyn:2
# ['Brooklyn', 'Park Slope', 40.67232052268197, -73.97705030183924]
# ( 72 / 306 ) Italian Resturants in Cypress Hills, Brooklyn:0
# ['Brooklyn', 'Cypress Hills', 40.68239101144211, -73.87661596457296]
# ( 73 / 306 ) Italian Resturants in East New York, Brooklyn:0
# ['Brooklyn', 'East New York', 40.669925700847045, -73.88069863917366]
# ( 74 / 306 ) Italian Resturants in Starrett City, Brooklyn:0
# ['Brooklyn', 'Starrett City', 40.64758905230874, -73.87936970045875]
# ( 75 / 306 ) Italian Resturants in Canarsie, Brooklyn:0
# ['Brooklyn', 'Canarsie', 40.63556432797428, -73.90209269778966]
# ( 76 / 306 ) Italian Resturants in Flatlands, Brooklyn:0
# ['Brooklyn', 'Flatlands', 40.630446043757466, -73.92911302644674]
# ( 77 / 306 ) Italian Resturants in Mill Island, Brooklyn:0
# ['Brooklyn', 'Mill Island', 40.606336421685626, -73.90818571777423]
# ( 78 / 306 ) Italian Resturants in Manhattan Beach, Brooklyn:0
# ['Brooklyn', 'Manhattan Beach', 40.57791350308657, -73.94353722891886]
# ( 79 / 306 ) Italian Resturants in Coney Island, Brooklyn:0
# ['Brooklyn', 'Coney Island', 40.57429256471601, -73.98868295821637]
# ( 80 / 306 ) Italian Resturants in Bath Beach, Brooklyn:2
# ['Brooklyn', 'Bath Beach', 40.59951870282238, -73.99875221443519]
# ( 81 / 306 ) Italian Resturants in Borough Park, Brooklyn:0
# ['Brooklyn', 'Borough Park', 40.633130512758015, -73.99049823044811]
# ( 82 / 306 ) Italian Resturants in Dyker Heights, Brooklyn:1
# ['Brooklyn', 'Dyker Heights', 40.619219457722636, -74.01931375636022]
# ( 83 / 306 ) Italian Resturants in Gerritsen Beach, Brooklyn:0
# ['Brooklyn', 'Gerritsen Beach', 40.590848433902046, -73.93010170691196]
# ( 84 / 306 ) Italian Resturants in Marine Park, Brooklyn:0
# ['Brooklyn', 'Marine Park', 40.609747779894604, -73.93134404108497]
# ( 85 / 306 ) Italian Resturants in Clinton Hill, Brooklyn:2
# ['Brooklyn', 'Clinton Hill', 40.693229421881504, -73.96784306216367]
# ( 86 / 306 ) Italian Resturants in Sea Gate, Brooklyn:0
# ['Brooklyn', 'Sea Gate', 40.57637537890224, -74.0078731120024]
# ( 87 / 306 ) Italian Resturants in Downtown, Brooklyn:2
# ['Brooklyn', 'Downtown', 40.69084402109802, -73.98346337431099]
# ( 88 / 306 ) Italian Resturants in Boerum Hill, Brooklyn:1
# ['Brooklyn', 'Boerum Hill', 40.685682912091444, -73.98374824115798]
# ( 89 / 306 ) Italian Resturants in Prospect Lefferts Gardens, Brooklyn:1
# ['Brooklyn', 'Prospect Lefferts Gardens', 40.658420017469815, -73.95489867077713]
# ( 90 / 306 ) Italian Resturants in Ocean Hill, Brooklyn:0
# ['Brooklyn', 'Ocean Hill', 40.678402554795355, -73.91306831787395]
# ( 91 / 306 ) Italian Resturants in City Line, Brooklyn:0
# ['Brooklyn', 'City Line', 40.67856995727479, -73.86797598081334]
# ( 92 / 306 ) Italian Resturants in Bergen Beach, Brooklyn:0
# ['Brooklyn', 'Bergen Beach', 40.61514955045308, -73.89855633630317]
# ( 93 / 306 ) Italian Resturants in Midwood, Brooklyn:1
# ['Brooklyn', 'Midwood', 40.62559589869843, -73.95759523489838]
# ( 94 / 306 ) Italian Resturants in Prospect Park South, Brooklyn:0
# ['Brooklyn', 'Prospect Park South', 40.647008603185185, -73.96261316716048]
# ( 95 / 306 ) Italian Resturants in Georgetown, Brooklyn:0
# ['Brooklyn', 'Georgetown', 40.62384524478419, -73.91607483951324]
# ( 96 / 306 ) Italian Resturants in East Williamsburg, Brooklyn:0
# ['Brooklyn', 'East Williamsburg', 40.70849241041548, -73.93885815269195]
# ( 97 / 306 ) Italian Resturants in North Side, Brooklyn:1
# ['Brooklyn', 'North Side', 40.714822906532014, -73.95880857587582]
# ( 98 / 306 ) Italian Resturants in South Side, Brooklyn:1
# ['Brooklyn', 'South Side', 40.71086147265064, -73.95800095153331]
# ( 99 / 306 ) Italian Resturants in Ocean Parkway, Brooklyn:0
# ['Brooklyn', 'Ocean Parkway', 40.61305976667942, -73.96836678035541]
# ( 100 / 306 ) Italian Resturants in Fort Hamilton, Brooklyn:2
# ['Brooklyn', 'Fort Hamilton', 40.61476812694226, -74.03197914537984]
# ( 101 / 306 ) Italian Resturants in Chinatown, Manhattan:1
# ['Manhattan', 'Chinatown', 40.71561842231432, -73.99427936255978]
# ( 102 / 306 ) Italian Resturants in Washington Heights, Manhattan:1
# ['Manhattan', 'Washington Heights', 40.85190252555305, -73.93690027985234]
# ( 103 / 306 ) Italian Resturants in Inwood, Manhattan:0
# ['Manhattan', 'Inwood', 40.86768396449915, -73.92121042203897]
# ( 104 / 306 ) Italian Resturants in Hamilton Heights, Manhattan:1
# ['Manhattan', 'Hamilton Heights', 40.823604284811935, -73.94968791883366]
# ( 105 / 306 ) Italian Resturants in Manhattanville, Manhattan:1
# ['Manhattan', 'Manhattanville', 40.8169344294978, -73.9573853935188]
# ( 106 / 306 ) Italian Resturants in Central Harlem, Manhattan:0
# ['Manhattan', 'Central Harlem', 40.81597606742414, -73.94321112603905]
# ( 107 / 306 ) Italian Resturants in East Harlem, Manhattan:0
# ['Manhattan', 'East Harlem', 40.79224946663033, -73.94418223148524]
# ( 108 / 306 ) Italian Resturants in Upper East Side, Manhattan:7
# ['Manhattan', 'Upper East Side', 40.775638573301805, -73.96050763135]
# ( 109 / 306 ) Italian Resturants in Yorkville, Manhattan:5
# ['Manhattan', 'Yorkville', 40.775929849884875, -73.94711784471826]
# ( 110 / 306 ) Italian Resturants in Lenox Hill, Manhattan:6
# ['Manhattan', 'Lenox Hill', 40.76811265828733, -73.9588596881376]
# ( 111 / 306 ) Italian Resturants in Roosevelt Island, Manhattan:0
# ['Manhattan', 'Roosevelt Island', 40.76215960576283, -73.94916769227953]
# ( 112 / 306 ) Italian Resturants in Upper West Side, Manhattan:3
# ['Manhattan', 'Upper West Side', 40.787657998534854, -73.97705923630603]
# ( 113 / 306 ) Italian Resturants in Lincoln Square, Manhattan:2
# ['Manhattan', 'Lincoln Square', 40.77352888942166, -73.98533777001262]
# ( 114 / 306 ) Italian Resturants in Clinton, Manhattan:3
# ['Manhattan', 'Clinton', 40.75910089146212, -73.99611936309479]
# ( 115 / 306 ) Italian Resturants in Midtown, Manhattan:0
# ['Manhattan', 'Midtown', 40.75469110270623, -73.98166882730304]
# ( 116 / 306 ) Italian Resturants in Murray Hill, Manhattan:3
# ['Manhattan', 'Murray Hill', 40.748303077252174, -73.97833207924127]
# ( 117 / 306 ) Italian Resturants in Chelsea, Manhattan:5
# ['Manhattan', 'Chelsea', 40.744034706747975, -74.00311633472813]
# ( 118 / 306 ) Italian Resturants in Greenwich Village, Manhattan:14
# ['Manhattan', 'Greenwich Village', 40.72693288536128, -73.99991402945902]
# ( 119 / 306 ) Italian Resturants in East Village, Manhattan:2
# ['Manhattan', 'East Village', 40.727846777270244, -73.98222616506416]
# ( 120 / 306 ) Italian Resturants in Lower East Side, Manhattan:1
# ['Manhattan', 'Lower East Side', 40.71780674892765, -73.98089031999291]
# ( 121 / 306 ) Italian Resturants in Tribeca, Manhattan:1
# ['Manhattan', 'Tribeca', 40.721521967443216, -74.01068328559087]
# ( 122 / 306 ) Italian Resturants in Little Italy, Manhattan:4
# ['Manhattan', 'Little Italy', 40.71932379395907, -73.99730467208073]
# ( 123 / 306 ) Italian Resturants in Soho, Manhattan:3
# ['Manhattan', 'Soho', 40.72218384131794, -74.00065666959759]
# ( 124 / 306 ) Italian Resturants in West Village, Manhattan:9
# ['Manhattan', 'West Village', 40.73443393572434, -74.00617998126812]
# ( 125 / 306 ) Italian Resturants in Manhattan Valley, Manhattan:1
# ['Manhattan', 'Manhattan Valley', 40.797307041702865, -73.96428617740655]
# ( 126 / 306 ) Italian Resturants in Morningside Heights, Manhattan:0
# ['Manhattan', 'Morningside Heights', 40.807999738165826, -73.96389627905332]
# ( 127 / 306 ) Italian Resturants in Gramercy, Manhattan:3
# ['Manhattan', 'Gramercy', 40.737209832715, -73.98137594833541]
# ( 128 / 306 ) Italian Resturants in Battery Park City, Manhattan:2
# ['Manhattan', 'Battery Park City', 40.71193198394565, -74.01686930508617]
# ( 129 / 306 ) Italian Resturants in Financial District, Manhattan:2
# ['Manhattan', 'Financial District', 40.70710710727048, -74.0106654452127]
# ( 130 / 306 ) Italian Resturants in Astoria, Queens:0
# ['Queens', 'Astoria', 40.76850859335492, -73.91565374304234]
# ( 131 / 306 ) Italian Resturants in Woodside, Queens:0
# ['Queens', 'Woodside', 40.74634908860222, -73.90184166838284]
# ( 132 / 306 ) Italian Resturants in Jackson Heights, Queens:0
# ['Queens', 'Jackson Heights', 40.75198138007367, -73.88282109164365]
# ( 133 / 306 ) Italian Resturants in Elmhurst, Queens:0
# ['Queens', 'Elmhurst', 40.744048505122024, -73.88165622288388]
# ( 134 / 306 ) Italian Resturants in Howard Beach, Queens:3
# ['Queens', 'Howard Beach', 40.65422527738487, -73.8381376460028]
# ( 135 / 306 ) Italian Resturants in Corona, Queens:1
# ['Queens', 'Corona', 40.74238175015667, -73.85682497345258]
# ( 136 / 306 ) Italian Resturants in Forest Hills, Queens:0
# ['Queens', 'Forest Hills', 40.72526378216503, -73.84447500788983]
# ( 137 / 306 ) Italian Resturants in Kew Gardens, Queens:0
# ['Queens', 'Kew Gardens', 40.7051790354148, -73.82981905825703]
# ( 138 / 306 ) Italian Resturants in Richmond Hill, Queens:0
# ['Queens', 'Richmond Hill', 40.69794731471763, -73.83183321446887]
# ( 139 / 306 ) Italian Resturants in Flushing, Queens:1
# ['Queens', 'Flushing', 40.76445419697846, -73.83177300329582]
# ( 140 / 306 ) Italian Resturants in Long Island City, Queens:1
# ['Queens', 'Long Island City', 40.75021734610528, -73.93920223915505]
# ( 141 / 306 ) Italian Resturants in Sunnyside, Queens:0
# ['Queens', 'Sunnyside', 40.74017628351924, -73.92691617561577]
# ( 142 / 306 ) Italian Resturants in East Elmhurst, Queens:0
# ['Queens', 'East Elmhurst', 40.76407323883091, -73.86704147658772]
# ( 143 / 306 ) Italian Resturants in Maspeth, Queens:1
# ['Queens', 'Maspeth', 40.725427374093606, -73.89621713626859]
# ( 144 / 306 ) Italian Resturants in Ridgewood, Queens:1
# ['Queens', 'Ridgewood', 40.70832315613858, -73.90143517559589]
# ( 145 / 306 ) Italian Resturants in Glendale, Queens:0
# ['Queens', 'Glendale', 40.70276242967838, -73.87074167435605]
# ( 146 / 306 ) Italian Resturants in Rego Park, Queens:1
# ['Queens', 'Rego Park', 40.72897409480735, -73.8578268690537]
# ( 147 / 306 ) Italian Resturants in Woodhaven, Queens:0
# ['Queens', 'Woodhaven', 40.68988687915789, -73.8581104655432]
# ( 148 / 306 ) Italian Resturants in Ozone Park, Queens:0
# ['Queens', 'Ozone Park', 40.680708468265415, -73.84320266173447]
# ( 149 / 306 ) Italian Resturants in South Ozone Park, Queens:0
# ['Queens', 'South Ozone Park', 40.66854957767195, -73.80986478649041]
# ( 150 / 306 ) Italian Resturants in College Point, Queens:0
# ['Queens', 'College Point', 40.784902749260205, -73.84304528896125]
# ( 151 / 306 ) Italian Resturants in Whitestone, Queens:0
# ['Queens', 'Whitestone', 40.78129076602694, -73.81420216610863]
# ( 152 / 306 ) Italian Resturants in Bayside, Queens:2
# ['Queens', 'Bayside', 40.76604063281064, -73.7742736306867]
# ( 153 / 306 ) Italian Resturants in Auburndale, Queens:1
# ['Queens', 'Auburndale', 40.76172954903262, -73.79176243728061]
# ( 154 / 306 ) Italian Resturants in Little Neck, Queens:2
# ['Queens', 'Little Neck', 40.7708261928267, -73.7388977558074]
# ( 155 / 306 ) Italian Resturants in Douglaston, Queens:1
# ['Queens', 'Douglaston', 40.76684609790763, -73.7424982072733]
# ( 156 / 306 ) Italian Resturants in Glen Oaks, Queens:0
# ['Queens', 'Glen Oaks', 40.74944079974332, -73.71548118999145]
# ( 157 / 306 ) Italian Resturants in Bellerose, Queens:1
# ['Queens', 'Bellerose', 40.72857318176675, -73.72012814826903]
# ( 158 / 306 ) Italian Resturants in Kew Gardens Hills, Queens:0
# ['Queens', 'Kew Gardens Hills', 40.722578244228046, -73.82087764933566]
# ( 159 / 306 ) Italian Resturants in Fresh Meadows, Queens:0
# ['Queens', 'Fresh Meadows', 40.7343944653313, -73.78271337003264]
# ( 160 / 306 ) Italian Resturants in Briarwood, Queens:0
# ['Queens', 'Briarwood', 40.71093547252271, -73.81174822458634]
# ( 161 / 306 ) Italian Resturants in Jamaica Center, Queens:0
# ['Queens', 'Jamaica Center', 40.70465736068717, -73.79690165888289]
# ( 162 / 306 ) Italian Resturants in Oakland Gardens, Queens:0
# ['Queens', 'Oakland Gardens', 40.74561857141855, -73.75494976234332]
# ( 163 / 306 ) Italian Resturants in Queens Village, Queens:0
# ['Queens', 'Queens Village', 40.718893092167356, -73.73871484578424]
# ( 164 / 306 ) Italian Resturants in Hollis, Queens:0
# ['Queens', 'Hollis', 40.71124344191904, -73.75925009335594]
# ( 165 / 306 ) Italian Resturants in South Jamaica, Queens:0
# ['Queens', 'South Jamaica', 40.696911253789885, -73.7904261313554]
# ( 166 / 306 ) Italian Resturants in St. Albans, Queens:0
# ['Queens', 'St. Albans', 40.69444538522359, -73.75867603727717]
# ( 167 / 306 ) Italian Resturants in Rochdale, Queens:0
# ['Queens', 'Rochdale', 40.67521139591733, -73.77258787620906]
# ( 168 / 306 ) Italian Resturants in Springfield Gardens, Queens:0
# ['Queens', 'Springfield Gardens', 40.666230490368584, -73.76042092682287]
# ( 169 / 306 ) Italian Resturants in Cambria Heights, Queens:0
# ['Queens', 'Cambria Heights', 40.692774639160845, -73.73526873708026]
# ( 170 / 306 ) Italian Resturants in Rosedale, Queens:0
# ['Queens', 'Rosedale', 40.659816433428084, -73.73526079428278]
# ( 171 / 306 ) Italian Resturants in Far Rockaway, Queens:0
# ['Queens', 'Far Rockaway', 40.603134432500894, -73.75497968043872]
# ( 172 / 306 ) Italian Resturants in Broad Channel, Queens:0
# ['Queens', 'Broad Channel', 40.60302658351238, -73.8200548911032]
# ( 173 / 306 ) Italian Resturants in Breezy Point, Queens:0
# ['Queens', 'Breezy Point', 40.55740128845452, -73.92551196994168]
# ( 174 / 306 ) Italian Resturants in Steinway, Queens:0
# ['Queens', 'Steinway', 40.775923015642896, -73.90228960391673]
# ( 175 / 306 ) Italian Resturants in Beechhurst, Queens:0
# ['Queens', 'Beechhurst', 40.79278140360048, -73.80436451720988]
# ( 176 / 306 ) Italian Resturants in Bay Terrace, Queens:0
# ['Queens', 'Bay Terrace', 40.782842806245554, -73.7768022262158]
# ( 177 / 306 ) Italian Resturants in Edgemere, Queens:0
# ['Queens', 'Edgemere', 40.595641807368494, -73.77613282391705]
# ( 178 / 306 ) Italian Resturants in Arverne, Queens:0
# ['Queens', 'Arverne', 40.58914394372971, -73.79199233136943]
# ( 179 / 306 ) Italian Resturants in Rockaway Beach, Queens:0
# ['Queens', 'Rockaway Beach', 40.582801696845586, -73.82236121088751]
# ( 180 / 306 ) Italian Resturants in Neponsit, Queens:0
# ['Queens', 'Neponsit', 40.572036730217015, -73.85754672410827]
# ( 181 / 306 ) Italian Resturants in Murray Hill, Queens:0
# ['Queens', 'Murray Hill', 40.764126122614066, -73.81276269135866]
# ( 182 / 306 ) Italian Resturants in Floral Park, Queens:0
# ['Queens', 'Floral Park', 40.741378421945434, -73.70884705889246]
# ( 183 / 306 ) Italian Resturants in Holliswood, Queens:0
# ['Queens', 'Holliswood', 40.7209572076444, -73.76714166714729]
# ( 184 / 306 ) Italian Resturants in Jamaica Estates, Queens:0
# ['Queens', 'Jamaica Estates', 40.71680483014613, -73.7872269693666]
# ( 185 / 306 ) Italian Resturants in Queensboro Hill, Queens:0
# ['Queens', 'Queensboro Hill', 40.7445723092867, -73.82580915110559]
# ( 186 / 306 ) Italian Resturants in Hillcrest, Queens:0
# ['Queens', 'Hillcrest', 40.723824901829204, -73.79760300912672]
# ( 187 / 306 ) Italian Resturants in Ravenswood, Queens:1
# ['Queens', 'Ravenswood', 40.761704526054146, -73.93157506072878]
# ( 188 / 306 ) Italian Resturants in Lindenwood, Queens:0
# ['Queens', 'Lindenwood', 40.66391841925139, -73.84963782402441]
# ( 189 / 306 ) Italian Resturants in Laurelton, Queens:0
# ['Queens', 'Laurelton', 40.66788389660247, -73.74025607989822]
# ( 190 / 306 ) Italian Resturants in Lefrak City, Queens:0
# ['Queens', 'Lefrak City', 40.736074570830795, -73.8625247141374]
# ( 191 / 306 ) Italian Resturants in Belle Harbor, Queens:0
# ['Queens', 'Belle Harbor', 40.57615556543109, -73.8540175039252]
# ( 192 / 306 ) Italian Resturants in Rockaway Park, Queens:0
# ['Queens', 'Rockaway Park', 40.58034295646131, -73.84153370226186]
# ( 193 / 306 ) Italian Resturants in Somerville, Queens:0
# ['Queens', 'Somerville', 40.59771061565768, -73.79664750844047]
# ( 194 / 306 ) Italian Resturants in Brookville, Queens:0
# ['Queens', 'Brookville', 40.66000322733613, -73.75175310731153]
# ( 195 / 306 ) Italian Resturants in Bellaire, Queens:0
# ['Queens', 'Bellaire', 40.73301404027834, -73.73889198912481]
# ( 196 / 306 ) Italian Resturants in North Corona, Queens:0
# ['Queens', 'North Corona', 40.7540709990489, -73.85751790676447]
# ( 197 / 306 ) Italian Resturants in Forest Hills Gardens, Queens:0
# ['Queens', 'Forest Hills Gardens', 40.7146110815117, -73.8410221123401]
# ( 198 / 306 ) Italian Resturants in St. George, Staten Island:2
# ['Staten Island', 'St. George', 40.6449815710044, -74.07935312512797]
# ( 199 / 306 ) Italian Resturants in New Brighton, Staten Island:0
# ['Staten Island', 'New Brighton', 40.64061455913511, -74.08701650516625]
# ( 200 / 306 ) Italian Resturants in Stapleton, Staten Island:0
# ['Staten Island', 'Stapleton', 40.62692762538176, -74.07790192660066]
# ( 201 / 306 ) Italian Resturants in Rosebank, Staten Island:1
# ['Staten Island', 'Rosebank', 40.61530494652761, -74.06980526716141]
# ( 202 / 306 ) Italian Resturants in West Brighton, Staten Island:2
# ['Staten Island', 'West Brighton', 40.63187892654607, -74.1071817826561]
# ( 203 / 306 ) Italian Resturants in Grymes Hill, Staten Island:0
# ['Staten Island', 'Grymes Hill', 40.624184791313006, -74.08724819983729]
# ( 204 / 306 ) Italian Resturants in Todt Hill, Staten Island:0
# ['Staten Island', 'Todt Hill', 40.59706851814673, -74.1113288180088]
# ( 205 / 306 ) Italian Resturants in South Beach, Staten Island:0
# ['Staten Island', 'South Beach', 40.58024741350956, -74.0795529253982]
# ( 206 / 306 ) Italian Resturants in Port Richmond, Staten Island:0
# ['Staten Island', 'Port Richmond', 40.63366930554365, -74.12943426797008]
# ( 207 / 306 ) Italian Resturants in Mariner's Harbor, Staten Island:2
# ['Staten Island', "Mariner's Harbor", 40.632546390481124, -74.15008537046981]
# ( 208 / 306 ) Italian Resturants in Port Ivory, Staten Island:0
# ['Staten Island', 'Port Ivory', 40.63968297845542, -74.17464532993542]
# ( 209 / 306 ) Italian Resturants in Castleton Corners, Staten Island:0
# ['Staten Island', 'Castleton Corners', 40.61333593766742, -74.11918058534842]
# ( 210 / 306 ) Italian Resturants in New Springville, Staten Island:0
# ['Staten Island', 'New Springville', 40.594252379161695, -74.16496031329827]
# ( 211 / 306 ) Italian Resturants in Travis, Staten Island:0
# ['Staten Island', 'Travis', 40.58631375103281, -74.19073717538116]
# ( 212 / 306 ) Italian Resturants in New Dorp, Staten Island:3
# ['Staten Island', 'New Dorp', 40.57257231820632, -74.1164794360638]
# ( 213 / 306 ) Italian Resturants in Oakwood, Staten Island:0
# ['Staten Island', 'Oakwood', 40.5584622432888, -74.12156593771896]
# ( 214 / 306 ) Italian Resturants in Great Kills, Staten Island:3
# ['Staten Island', 'Great Kills', 40.549480228713605, -74.14932381490992]
# ( 215 / 306 ) Italian Resturants in Eltingville, Staten Island:3
# ['Staten Island', 'Eltingville', 40.542230747450745, -74.1643308041936]
# ( 216 / 306 ) Italian Resturants in Annadale, Staten Island:0
# ['Staten Island', 'Annadale', 40.53811417474507, -74.17854866165878]
# ( 217 / 306 ) Italian Resturants in Woodrow, Staten Island:1
# ['Staten Island', 'Woodrow', 40.541967622888755, -74.20524582480326]
# ( 218 / 306 ) Italian Resturants in Tottenville, Staten Island:0
# ['Staten Island', 'Tottenville', 40.50533376115642, -74.24656934235283]
# ( 219 / 306 ) Italian Resturants in Tompkinsville, Staten Island:0
# ['Staten Island', 'Tompkinsville', 40.637316067110326, -74.08055351790115]
# ( 220 / 306 ) Italian Resturants in Silver Lake, Staten Island:0
# ['Staten Island', 'Silver Lake', 40.61919310792676, -74.09629029235458]
# ( 221 / 306 ) Italian Resturants in Sunnyside, Staten Island:0
# ['Staten Island', 'Sunnyside', 40.61276015756489, -74.0971255217853]
# ( 222 / 306 ) Italian Resturants in Ditmas Park, Brooklyn:0
# ['Brooklyn', 'Ditmas Park', 40.643675183340974, -73.96101312466779]
# ( 223 / 306 ) Italian Resturants in Wingate, Brooklyn:0
# ['Brooklyn', 'Wingate', 40.66094656188111, -73.93718680559314]
# ( 224 / 306 ) Italian Resturants in Rugby, Brooklyn:0
# ['Brooklyn', 'Rugby', 40.655572313280764, -73.92688212616955]
# ( 225 / 306 ) Italian Resturants in Park Hill, Staten Island:0
# ['Staten Island', 'Park Hill', 40.60919044434558, -74.08015734936296]
# ( 226 / 306 ) Italian Resturants in Westerleigh, Staten Island:0
# ['Staten Island', 'Westerleigh', 40.62109047275409, -74.13304143951704]
# ( 227 / 306 ) Italian Resturants in Graniteville, Staten Island:0
# ['Staten Island', 'Graniteville', 40.620171512231884, -74.15315246387762]
# ( 228 / 306 ) Italian Resturants in Arlington, Staten Island:0
# ['Staten Island', 'Arlington', 40.63532509911492, -74.16510420241124]
# ( 229 / 306 ) Italian Resturants in Arrochar, Staten Island:2
# ['Staten Island', 'Arrochar', 40.596312571276734, -74.06712363225574]
# ( 230 / 306 ) Italian Resturants in Grasmere, Staten Island:1
# ['Staten Island', 'Grasmere', 40.59826835959991, -74.0766743627905]
# ( 231 / 306 ) Italian Resturants in Old Town, Staten Island:3
# ['Staten Island', 'Old Town', 40.59632891379513, -74.08751118005578]
# ( 232 / 306 ) Italian Resturants in Dongan Hills, Staten Island:0
# ['Staten Island', 'Dongan Hills', 40.588672948199275, -74.09639905312521]
# ( 233 / 306 ) Italian Resturants in Midland Beach, Staten Island:0
# ['Staten Island', 'Midland Beach', 40.57352690574283, -74.09348266303591]
# ( 234 / 306 ) Italian Resturants in Grant City, Staten Island:0
# ['Staten Island', 'Grant City', 40.57621558711788, -74.10585598545434]
# ( 235 / 306 ) Italian Resturants in New Dorp Beach, Staten Island:2
# ['Staten Island', 'New Dorp Beach', 40.56425549307335, -74.10432707469124]
# ( 236 / 306 ) Italian Resturants in Bay Terrace, Staten Island:2
# ['Staten Island', 'Bay Terrace', 40.55398800858462, -74.13916622175768]
# ( 237 / 306 ) Italian Resturants in Huguenot, Staten Island:1
# ['Staten Island', 'Huguenot', 40.531911920489605, -74.19174105747814]
# ( 238 / 306 ) Italian Resturants in Pleasant Plains, Staten Island:0
# ['Staten Island', 'Pleasant Plains', 40.524699376118136, -74.21983106616777]
# ( 239 / 306 ) Italian Resturants in Butler Manor, Staten Island:0
# ['Staten Island', 'Butler Manor', 40.50608165346305, -74.22950350260027]
# ( 240 / 306 ) Italian Resturants in Charleston, Staten Island:0
# ['Staten Island', 'Charleston', 40.53053148283314, -74.23215775896526]
# ( 241 / 306 ) Italian Resturants in Rossville, Staten Island:0
# ['Staten Island', 'Rossville', 40.54940400650072, -74.21572851113952]
# ( 242 / 306 ) Italian Resturants in Arden Heights, Staten Island:0
# ['Staten Island', 'Arden Heights', 40.54928582278321, -74.18588674583893]
# ( 243 / 306 ) Italian Resturants in Greenridge, Staten Island:0
# ['Staten Island', 'Greenridge', 40.555295236173194, -74.17079414786092]
# ( 244 / 306 ) Italian Resturants in Heartland Village, Staten Island:0
# ['Staten Island', 'Heartland Village', 40.58913894875281, -74.15902208156601]
# ( 245 / 306 ) Italian Resturants in Chelsea, Staten Island:1
# ['Staten Island', 'Chelsea', 40.59472602746295, -74.1895604551969]
# ( 246 / 306 ) Italian Resturants in Bloomfield, Staten Island:0
# ['Staten Island', 'Bloomfield', 40.60577868452358, -74.18725638381567]
# ( 247 / 306 ) Italian Resturants in Bulls Head, Staten Island:0
# ['Staten Island', 'Bulls Head', 40.6095918004203, -74.15940948657122]
# ( 248 / 306 ) Italian Resturants in Carnegie Hill, Manhattan:2
# ['Manhattan', 'Carnegie Hill', 40.7826825671257, -73.95325646837112]
# ( 249 / 306 ) Italian Resturants in Noho, Manhattan:6
# ['Manhattan', 'Noho', 40.72325901885768, -73.98843368023597]
# ( 250 / 306 ) Italian Resturants in Civic Center, Manhattan:6
# ['Manhattan', 'Civic Center', 40.71522892046282, -74.00541529873355]
# ( 251 / 306 ) Italian Resturants in Midtown South, Manhattan:1
# ['Manhattan', 'Midtown South', 40.7485096643122, -73.98871313285247]
# ( 252 / 306 ) Italian Resturants in Richmond Town, Staten Island:0
# ['Staten Island', 'Richmond Town', 40.56960594275505, -74.1340572986257]
# ( 253 / 306 ) Italian Resturants in Shore Acres, Staten Island:3
# ['Staten Island', 'Shore Acres', 40.60971934079284, -74.06667766061771]
# ( 254 / 306 ) Italian Resturants in Clifton, Staten Island:0
# ['Staten Island', 'Clifton', 40.61917845202843, -74.072642445484]
# ( 255 / 306 ) Italian Resturants in Concord, Staten Island:0
# ['Staten Island', 'Concord', 40.6044731896879, -74.08402364740358]
# ( 256 / 306 ) Italian Resturants in Emerson Hill, Staten Island:0
# ['Staten Island', 'Emerson Hill', 40.606794394801, -74.09776206972522]
# ( 257 / 306 ) Italian Resturants in Randall Manor, Staten Island:0
# ['Staten Island', 'Randall Manor', 40.63563000681151, -74.09805062373887]
# ( 258 / 306 ) Italian Resturants in Howland Hook, Staten Island:0
# ['Staten Island', 'Howland Hook', 40.63843283794795, -74.18622331749823]
# ( 259 / 306 ) Italian Resturants in Elm Park, Staten Island:0
# ['Staten Island', 'Elm Park', 40.630146741193826, -74.1418167896889]
# ( 260 / 306 ) Italian Resturants in Remsen Village, Brooklyn:0
# ['Brooklyn', 'Remsen Village', 40.652117451793494, -73.91665331978048]
# ( 261 / 306 ) Italian Resturants in New Lots, Brooklyn:0
# ['Brooklyn', 'New Lots', 40.6627442796966, -73.88511776379292]
# ( 262 / 306 ) Italian Resturants in Paerdegat Basin, Brooklyn:0
# ['Brooklyn', 'Paerdegat Basin', 40.63131755039667, -73.90233474295836]
# ( 263 / 306 ) Italian Resturants in Mill Basin, Brooklyn:0
# ['Brooklyn', 'Mill Basin', 40.61597423962336, -73.91515391550404]
# ( 264 / 306 ) Italian Resturants in Jamaica Hills, Queens:0
# ['Queens', 'Jamaica Hills', 40.71145964370482, -73.79646462081593]
# ( 265 / 306 ) Italian Resturants in Utopia, Queens:0
# ['Queens', 'Utopia', 40.73350025429757, -73.79671678028349]
# ( 266 / 306 ) Italian Resturants in Pomonok, Queens:0
# ['Queens', 'Pomonok', 40.73493618075478, -73.80486120040537]
# ( 267 / 306 ) Italian Resturants in Astoria Heights, Queens:1
# ['Queens', 'Astoria Heights', 40.7703173929982, -73.89467996270574]
# ( 268 / 306 ) Italian Resturants in Claremont Village, Bronx:0
# ['Bronx', 'Claremont Village', 40.83142834161548, -73.90119903387667]
# ( 269 / 306 ) Italian Resturants in Concourse Village, Bronx:1
# ['Bronx', 'Concourse Village', 40.824780490842905, -73.91584652759009]
# ( 270 / 306 ) Italian Resturants in Mount Eden, Bronx:0
# ['Bronx', 'Mount Eden', 40.84382617671654, -73.91655551964419]
# ( 271 / 306 ) Italian Resturants in Mount Hope, Bronx:0
# ['Bronx', 'Mount Hope', 40.84884160724665, -73.90829930881988]
# ( 272 / 306 ) Italian Resturants in Sutton Place, Manhattan:4
# ['Manhattan', 'Sutton Place', 40.76028033131374, -73.96355614094303]
# ( 273 / 306 ) Italian Resturants in Hunters Point, Queens:3
# ['Queens', 'Hunters Point', 40.743414090073536, -73.95386782130745]
# ( 274 / 306 ) Italian Resturants in Turtle Bay, Manhattan:5
# ['Manhattan', 'Turtle Bay', 40.75204236950722, -73.96770824581834]
# ( 275 / 306 ) Italian Resturants in Tudor City, Manhattan:0
# ['Manhattan', 'Tudor City', 40.746917410740195, -73.97121928722265]
# ( 276 / 306 ) Italian Resturants in Stuyvesant Town, Manhattan:0
# ['Manhattan', 'Stuyvesant Town', 40.73099955477061, -73.97405170469203]
# ( 277 / 306 ) Italian Resturants in Flatiron, Manhattan:3
# ['Manhattan', 'Flatiron', 40.739673047638426, -73.9909471052826]
# ( 278 / 306 ) Italian Resturants in Sunnyside Gardens, Queens:1
# ['Queens', 'Sunnyside Gardens', 40.74565180608076, -73.91819286431682]
# ( 279 / 306 ) Italian Resturants in Blissville, Queens:0
# ['Queens', 'Blissville', 40.73725071694497, -73.93244235260178]
# ( 280 / 306 ) Italian Resturants in Fulton Ferry, Brooklyn:1
# ['Brooklyn', 'Fulton Ferry', 40.70328109093014, -73.99550751888415]
# ( 281 / 306 ) Italian Resturants in Vinegar Hill, Brooklyn:0
# ['Brooklyn', 'Vinegar Hill', 40.70332149882874, -73.98111603592393]
# ( 282 / 306 ) Italian Resturants in Weeksville, Brooklyn:0
# ['Brooklyn', 'Weeksville', 40.67503986503237, -73.93053108817338]
# ( 283 / 306 ) Italian Resturants in Broadway Junction, Brooklyn:0
# ['Brooklyn', 'Broadway Junction', 40.67786104769531, -73.90331684852599]
# ( 284 / 306 ) Italian Resturants in Dumbo, Brooklyn:1
# ['Brooklyn', 'Dumbo', 40.70317632822692, -73.9887528074504]
# ( 285 / 306 ) Italian Resturants in Manor Heights, Staten Island:0
# ['Staten Island', 'Manor Heights', 40.60180957631444, -74.12059399718001]
# ( 286 / 306 ) Italian Resturants in Willowbrook, Staten Island:0
# ['Staten Island', 'Willowbrook', 40.60370692627371, -74.13208447484298]
# ( 287 / 306 ) Italian Resturants in Sandy Ground, Staten Island:0
# ['Staten Island', 'Sandy Ground', 40.541139922091766, -74.21776636068567]
# ( 288 / 306 ) Italian Resturants in Egbertville, Staten Island:0
# ['Staten Island', 'Egbertville', 40.579118742961214, -74.12727240604946]
# ( 289 / 306 ) Italian Resturants in Roxbury, Queens:0
# ['Queens', 'Roxbury', 40.56737588957032, -73.89213760232822]
# ( 290 / 306 ) Italian Resturants in Homecrest, Brooklyn:0
# ['Brooklyn', 'Homecrest', 40.598525095137255, -73.95918459428702]
# ( 291 / 306 ) Italian Resturants in Middle Village, Queens:0
# ['Queens', 'Middle Village', 40.716414511158185, -73.88114319200604]
# ( 292 / 306 ) Italian Resturants in Prince's Bay, Staten Island:1
# ['Staten Island', "Prince's Bay", 40.52626406734812, -74.20152556457658]
# ( 293 / 306 ) Italian Resturants in Lighthouse Hill, Staten Island:1
# ['Staten Island', 'Lighthouse Hill', 40.57650629379489, -74.13792663771568]
# ( 294 / 306 ) Italian Resturants in Richmond Valley, Staten Island:0
# ['Staten Island', 'Richmond Valley', 40.51954145748909, -74.22957080626941]
# ( 295 / 306 ) Italian Resturants in Malba, Queens:0
# ['Queens', 'Malba', 40.79060155670148, -73.82667757138641]
# ( 296 / 306 ) Italian Resturants in Highland Park, Brooklyn:0
# ['Brooklyn', 'Highland Park', 40.6819989345173, -73.890345709872]
# ( 297 / 306 ) Italian Resturants in Madison, Brooklyn:0
# ['Brooklyn', 'Madison', 40.60937770113766, -73.94841515328893]
# ( 298 / 306 ) Italian Resturants in Bronxdale, Bronx:0
# ['Bronx', 'Bronxdale', 40.85272297633017, -73.86172577555115]
# ( 299 / 306 ) Italian Resturants in Allerton, Bronx:0
# ['Bronx', 'Allerton', 40.86578787802982, -73.85931863221647]
# ( 300 / 306 ) Italian Resturants in Kingsbridge Heights, Bronx:0
# ['Bronx', 'Kingsbridge Heights', 40.8703923914147, -73.90152264513144]
# ( 301 / 306 ) Italian Resturants in Erasmus, Brooklyn:0
# ['Brooklyn', 'Erasmus', 40.64692606658579, -73.94817709920184]
# ( 302 / 306 ) Italian Resturants in Hudson Yards, Manhattan:0
# ['Manhattan', 'Hudson Yards', 40.75665808227519, -74.00011136202637]
# ( 303 / 306 ) Italian Resturants in Hammels, Queens:0
# ['Queens', 'Hammels', 40.58733774018741, -73.80553002968718]
# ( 304 / 306 ) Italian Resturants in Bayswater, Queens:0
# ['Queens', 'Bayswater', 40.611321691283834, -73.76596781445627]
# ( 305 / 306 ) Italian Resturants in Queensbridge, Queens:0
# ['Queens', 'Queensbridge', 40.756091297094706, -73.94563070334091]
# ( 306 / 306 ) Italian Resturants in Fox Hills, Staten Island:0
# ['Staten Island', 'Fox Hills', 40.61731079252983, -74.08173992211962]

# %%
italian_rest_ny.to_csv('italian_rest_ny_tocsv1.csv')
italian_rest_ny = pd.read_csv('italian_rest_ny_tocsv1.csv')
italian_rest_ny.tail()
# Out:
#      Unnamed: 0        Borough       Neighborhood                        ID  \
# 232         232         Queens  Sunnyside Gardens  5699aa86498ef437b2fd7102
# 233         233       Brooklyn       Fulton Ferry  593c0d2262420b7feccc3048
# 234         234       Brooklyn              Dumbo  593c0d2262420b7feccc3048
# 235         235  Staten Island       Prince's Bay  4c091311a1b32d7f5efb96f0
# 236         236  Staten Island    Lighthouse Hill  5079ccdce4b065f1dd8155ad
#
#                                  Name
# 232                         Zio Luigi
# 233                         Cecconi's
# 234                         Cecconi's
# 235  Certo's Gourmet Foods & Caterers
# 236                        Casa verde

# %% [markdown]
# As we continue our analysis, we see below that although Manhattan had the least number of nieghborhoods, it does have the highest number if Italian restaurants.  Additionally, we see how many restaurants the top 6 neighborhoods have.  The neighborhood of Belmont has the highest number of Italian restaurants in all of NYC and is actually located in the burough of Bronx vice Manhattan.

# %%
italian_rest_ny.groupby('Borough')['ID'].count().plot.bar(figsize=(10,5), color = 'red')
plt.title('Italian Resturants per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of Italian Resturants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
NOofNeigh = 6 # top number for graphing all the same past 6
italian_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(NOofNeigh).plot.bar(figsize=(10,5), color='blue')
plt.title('Italian Resturants per Neighborhood: NYC', fontsize = 20)
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('Italian Resturants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
italian_rest_ny[italian_rest_ny['Neighborhood']=='Belmont']
# Out:
#     Unnamed: 0 Borough Neighborhood                        ID  \
# 5            5   Bronx      Belmont  4acf80aef964a52025d420e3
# 6            6   Bronx      Belmont  4af71916f964a520cf0522e3
# 7            7   Bronx      Belmont  59050f51b23dfa5f6649e678
# 8            8   Bronx      Belmont  4bb6470cef159c7465b275f7
# 9            9   Bronx      Belmont  4aa425bef964a5208e4520e3
# 10          10   Bronx      Belmont  4bc22a22920eb713bcc51b2c
# 11          11   Bronx      Belmont  4af0fa29f964a52060e021e3
# 12          12   Bronx      Belmont  4b5514c4f964a5207cda27e3
# 13          13   Bronx      Belmont  4aa193d5f964a520124120e3
# 14          14   Bronx      Belmont  4b5a4c8ff964a52049bb28e3
# 15          15   Bronx      Belmont  4c79d294278eb713f6a05580
# 16          16   Bronx      Belmont  4c9b9e7b9c663704b90463fd
# 17          17   Bronx      Belmont  4b5bc595f964a520431529e3
# 18          18   Bronx      Belmont  4cb0d382ef1b370419643e00
# 19          19   Bronx      Belmont  4bc67f1104e8b713a833362d
# 20          20   Bronx      Belmont  53ff939c498e6b601dfa3979
# 21          21   Bronx      Belmont  44941e38f964a52081341fe3
#
#                                                  Name
# 5                                 Tino's Delicatessen
# 6   Michaelangelo's Coal Fired Brick Oven Pizza Re...
# 7                                Arthur Avenue Fiasco
# 8                                 Calabria Pork Store
# 9                               Dominick's Restaurant
# 10                                         Tra Di Noi
# 11                                Antonio's Trattoria
# 12                                             Enzo's
# 13                      Mario's Restaurant & Catering
# 14                                Emilia's Restaurant
# 15                                    Cafe al Mercato
# 16                                 Gerbasi Ristorante
# 17                              Pasquale Riggaletto's
# 18              David Greco's Arthur Avenue Trattoria
# 19  Ann & Tony's - An Original Arthur Avenue Resta...
# 20                             San Gennaro Ristorante
# 21                                 Arthur Avenue Cafe

# %%
italian_rest_ny.drop('Unnamed: 0',axis=1,inplace=True)
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
italian_rest_ny.head()
# Out:
#   Borough    Neighborhood                        ID                       Name
# 0   Bronx        Woodlawn  511edb6de4b0d58346fd272d     Patrizia's Of Woodlawn
# 1   Bronx  Pelham Parkway  4bf96ae65317a593d837017f                     Enzo's
# 2   Bronx  Pelham Parkway  4b47f069f964a5208c4426e3                Pasta Pasta
# 3   Bronx     City Island  4514ed4df964a520e5391fe3  Artie's Steak and Seafood
# 4   Bronx     Morris Park  4b10591af964a5205f6e23e3                 Patricia's

# %%
italian_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1
for row in italian_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(italian_rest_ny),')','processed')
    italian_rest_stats_ny = italian_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
italian_rest_stats_ny.tail()
# Out:
# {'meta': {'code': 200, 'requestId': '5de0bdfe9388d7001be00465'}, 'response': {'venue': {'id': '511edb6de4b0d58346fd272d', 'name': "Patrizia's Of Woodlawn", 'contact': {'phone': '7188845700', 'formattedPhone': '(718) 884-5700'}, 'location': {'address': '4358 Katonah Ave', 'lat': 40.900638399332884, 'lng': -73.86772361835486, 'labeledLatLngs': [{'label': 'display', 'lat': 40.900638399332884, 'lng': -73.86772361835486}], 'postalCode': '10470', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['4358 Katonah Ave', 'Bronx, NY 10470', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/patrizias-of-woodlawn/511edb6de4b0d58346fd272d', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 14}, 'url': 'http://patriziaspizza.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 18, 'groups': [{'type': 'others', 'count': 18, 'items': []}], 'summary': '18 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 30, 'delivery': {'id': '277050', 'url': 'https://www.seamless.com/menu/patrizias-of-woodlawn-4358-katonah-ave-bronx/277050?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=277050', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://patriziaspizza.com/restaurants/ny/bronx/10470/patrizia-s-of-woodlawn/menu/', 'mobileUrl': 'http://patriziaspizza.com/restaurants/ny/bronx/10470/patrizia-s-of-woodlawn/menu/', 'externalUrl': 'http://patriziaspizza.com/restaurants/ny/bronx/10470/patrizia-s-of-woodlawn/menu/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 11, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 11, 'items': [{'id': '532e0a61498eed2c785dd473', 'createdAt': 1395526241, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/5383181_SOrG_qTDBC4leb-IKQkMZ4neyLGcYb6kv-TKoaclgfo.jpg', 'width': 960, 'height': 720, 'user': {'id': '5383181', 'firstName': 'Chris', 'lastName': 'Slattery', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/HKBQXMXQP5CRAMMA.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1360976749, 'tips': {'count': 14, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 14, 'items': [{'id': '5224c1da11d2bcafc67dfb44', 'createdAt': 1378140634, 'text': "Coconut shrimp was great! Ravioli with vodka sauce was really good. Chicken parm was okay. They're almond cake was like an orgasm in your mouth.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5224c1da11d2bcafc67dfb44', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '88943233', 'firstName': 'Leo', 'lastName': 'Medina', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/88943233-FMS5GHMVZCEMEUYV.jpg'}}, {'id': '72997288', 'firstName': 'Catherine', 'lastName': 'Tenety-Basile', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/72997288-AEQY5BXU4T2FWGS4.jpg'}}, {'id': '59310624', 'firstName': 'Letizia Maria', 'lastName': 'Siino', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/C01DJJBXZBULPAQM.jpg'}}]}], 'sum ...
#                          ID                    Name  Likes  Rating  Tips
# 0  511edb6de4b0d58346fd272d  Patrizia's Of Woodlawn     18     8.3    14
# ( 1 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0be0578a48400282412ee'}, 'response': {'venue': {'id': '4bf96ae65317a593d837017f', 'name': "Enzo's", 'contact': {'phone': '7184093828', 'formattedPhone': '(718) 409-3828'}, 'location': {'address': '1998 Williamsbridge Rd', 'lat': 40.854232311821725, 'lng': -73.85436243306151, 'labeledLatLngs': [{'label': 'display', 'lat': 40.854232311821725, 'lng': -73.85436243306151}], 'postalCode': '10461', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1998 Williamsbridge Rd', 'Bronx, NY 10461', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/enzos/4bf96ae65317a593d837017f', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 10}, 'url': 'http://www.enzosofthebronx.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 25, 'groups': [{'type': 'others', 'count': 25, 'items': []}], 'summary': '25 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 39, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 30, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 30, 'items': [{'id': '4ef923530e61a0846ef01016', 'createdAt': 1324950355, 'source': {'name': 'Hipster', 'url': 'http://www.hipster.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/PMDKJWEHUBIVYWO3WW3AU0BHY5LCV3C53AAN2OA5IUKI441Y.jpg', 'width': 720, 'height': 480, 'user': {'id': '17669540', 'firstName': 'Megan Tinder Moran', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/KWBA1CJSXM1Q4KLM.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1274637030, 'tips': {'count': 10, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 10, 'items': [{'id': '5444272e498ecb4a7f552c95', 'createdAt': 1413752622, 'text': "Everything here is absolutely delicious, and incredibly authentic. The chicken parm was the best I've ever had and the wait staff was extremely nice and attentive too!", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5444272e498ecb4a7f552c95', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '2909631', 'firstName': 'Dani', 'lastName': "O'Neil", 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2909631-VXMA2GHVCDSK2GIO.jpg'}}, {'id': '10732616', 'firstName': 'Whitney', 'lastName': 'Shaw', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/V0TAXTRMCCSEEXGN.jpg'}}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '14157037', 'firstName': 'Corley', 'lastName': 'Stone', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/WX0QOPQTPPCN0Y1V.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/cr64JF', 'timeZone': 'America/New_York', 'listed': {'count': 14, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 14, 'items': [{'id': '558b075d498e58a049f20e97', 'name': 'Best Places to Eat', 'description': 'These are my favorite places to eat.', 'type': 'others', 'user': {'id': '109030117', 'firstName': 'Avery', 'lastName': 'Putter', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/109030117-13LV5DONRBHIBGT2.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/averyputter/list/best-places-to-eat', 'canonicalUrl': 'https://foursquare.com/averyputter/list ...
#                          ID    Name  Likes  Rating  Tips
# 0  4bf96ae65317a593d837017f  Enzo's     25     8.6    10
# ( 2 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0bdf1882fc7001bad0cba'}, 'response': {'venue': {'id': '4b47f069f964a5208c4426e3', 'name': 'Pasta Pasta', 'contact': {'phone': '7188929634', 'formattedPhone': '(718) 892-9634'}, 'location': {'address': '2023 Williamsbridge Rd', 'lat': 40.85478806485715, 'lng': -73.85492881053774, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85478806485715, 'lng': -73.85492881053774}], 'postalCode': '10461', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2023 Williamsbridge Rd', 'Bronx, NY 10461', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/pasta-pasta/4b47f069f964a5208c4426e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 8}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 9, 'groups': [{'type': 'others', 'count': 9, 'items': [{'id': '440317573', 'firstName': 'Michael', 'lastName': 'Reilly', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/440317573_4w70po26_4R4zGEKAV0aH4qTQ4EyBkB-20EaYTf8b9HDYNFSeqqtBEiHxZ0lEXIAjWLpr8kWg.jpg'}}, {'id': '462941637', 'firstName': 'Sue', 'lastName': 'Ellen', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/462941637_GnZrc94K_zPwsufeRsSQBkfOsQLFC23bGJpN1DJNsQv2vZOw5IvDTStfAuDgpPXwLplUgDsyb.jpg'}}, {'id': '120967279', 'firstName': 'Alex', 'lastName': 'Pimentel', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, {'id': '21369538', 'firstName': 'Myriam', 'lastName': 'Copicotto', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/JEDTT35RLSI3JBE1.jpg'}}]}], 'summary': '9 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.4, 'ratingColor': 'FFC800', 'ratingSignals': 21, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 11, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 11, 'items': [{'id': '5d8681ae6d0390000829909a', 'createdAt': 1569096110, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/42085913_1WAYLfAPfivinkThkpeZaqPUF46-YTi6yWfCjNP4b3c.jpg', 'width': 1346, 'height': 1920, 'user': {'id': '42085913', 'firstName': 'Ciaran', 'lastName': 'Groarke', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/BCH20H3ZIV304M4H.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1263005801, 'tips': {'count': 8, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 8, 'items': [{'id': '5312697111d292c46531f55e', 'createdAt': 1393715569, 'text': "Someone just keeled over right next to me! It's like the nursing home of Italian food....no pun intended!", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5312697111d292c46531f55e', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': []}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '23150174', 'firstName': 'Daniel', 'lastName': 'Fontanez', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/1MM2RWFE3R45WB5V.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/8eIstm', 'timeZone': 'America/New_York', 'listed': {'count': 4, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 4, 'items': [{'id': '4e6109deb3ad629a3a4ac4cb', 'name': '20 Favorite Restaurants', 'description': '', 'type': 'others', 'user' ...
#                          ID         Name  Likes  Rating  Tips
# 0  4b47f069f964a5208c4426e3  Pasta Pasta      9     6.4     8
# ( 3 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0be01b9a389001b00bfa4'}, 'response': {'venue': {'id': '4514ed4df964a520e5391fe3', 'name': "Artie's Steak and Seafood", 'contact': {'phone': '7188859885', 'formattedPhone': '(718) 885-9885', 'twitter': 'artiescrazy'}, 'location': {'address': '394 City Island Ave', 'lat': 40.849542144998146, 'lng': -73.78731730033616, 'labeledLatLngs': [{'label': 'display', 'lat': 40.849542144998146, 'lng': -73.78731730033616}], 'postalCode': '10464', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['394 City Island Ave', 'Bronx, NY 10464', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/arties-steak-and-seafood/4514ed4df964a520e5391fe3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 27}, 'url': 'http://www.artiescityisland.com', 'price': {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 44, 'groups': [{'type': 'others', 'count': 44, 'items': []}], 'summary': '44 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 74, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/arties-steak-and-seafood/4514ed4df964a520e5391fe3/menu', 'mobileUrl': 'https://foursquare.com/v/4514ed4df964a520e5391fe3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 41, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 41, 'items': [{'id': '512031f8e4b00ebaf9f770b8', 'createdAt': 1361064440, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/38056345_YxrGWXl-qI1x3rbV3Uu_v2XJwDacrRYzFlEWyQ_28mY.jpg', 'width': 717, 'height': 959, 'user': {'id': '38056345', 'firstName': 'Paula', 'lastName': 'Jerman', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/38056345-AEXWIUQMRFWK5O40.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1158999373, 'tips': {'count': 27, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 27, 'items': [{'id': '534eeafa498e3b48057eebd7', 'createdAt': 1397680890, 'text': "If you're a fan of seafood, make sure to travel to City Island and enjoy the delicious dishes of Arties, particularly the captains platter & the Broiled Fisherman Platters!", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/534eeafa498e3b48057eebd7', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': []}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '13889528', 'firstName': 'New York Habitat', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/PGPPIGGHW44SEI4X.jpg'}, 'type': 'chain'}}]}]}, 'shortUrl': 'http://4sq.com/aMr4jJ', 'timeZone': 'America/New_York', 'listed': {'count': 23, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 23, 'items': [{'id': '51ade096498e47fa587bb37a', 'name': 'The List', 'description': '', 'type': 'others', 'user': {'id': '225', 'firstName': 'Paul', 'lastName': 'K', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/225_1234044934.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/225/list/the-list', 'canonicalUrl': 'https://foursquare.com/user/225/list/the-lis ...
#                          ID                       Name  Likes  Rating  Tips
# 0  4514ed4df964a520e5391fe3  Artie's Steak and Seafood     44     8.1    27
# ( 4 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0be009388d7001be00927'}, 'response': {'venue': {'id': '4b10591af964a5205f6e23e3', 'name': "Patricia's", 'contact': {'phone': '7184099069', 'formattedPhone': '(718) 409-9069', 'twitter': 'patriciasnyc'}, 'location': {'address': '1082 Morris Park Ave', 'lat': 40.84931298339339, 'lng': -73.85353576737785, 'labeledLatLngs': [{'label': 'display', 'lat': 40.84931298339339, 'lng': -73.85353576737785}], 'postalCode': '10461', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1082 Morris Park Ave', 'Bronx, NY 10461', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/patricias/4b10591af964a5205f6e23e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 39}, 'url': 'http://www.patriciasnyc.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 84, 'groups': [{'type': 'others', 'count': 84, 'items': []}], 'summary': '84 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 127, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/patricias/4b10591af964a5205f6e23e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b10591af964a5205f6e23e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 85, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 85, 'items': [{'id': '58ffca495c1ba27da144f19e', 'createdAt': 1493158473, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/410402136_hSIRilYgmzCTOPJ8kV9Y-6vH1Kel7RsEZpOOlSNA0SI.jpg', 'width': 1500, 'height': 1000, 'user': {'id': '410402136', 'firstName': "Patricia's", 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/410402136_xpP1EHtY_soAbaTPVnrcSzhGwY_xHrs_u1vGt0j07kecJ6-cVPUKx61Yr3ydYzuRXWjyi4j9I.png'}, 'type': 'venuePage', 'venue': {'id': '4b10591af964a5205f6e23e3'}}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '410402136'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Our passion for the cuisine, wine, and regions of Italy are reflected throughout our restaurant.', 'page': {'user': {'id': '410402136', 'firstName': "Patricia's", 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/410402136_xpP1EHtY_soAbaTPVnrcSzhGwY_xHrs_u1vGt0j07kecJ6-cVPUKx61Yr3ydYzuRXWjyi4j9I.png'}, 'type': 'venuePage', 'venue': {'id': '4b10591af964a5205f6e23e3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'Bronx, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1259362586, 'tips': {'count': 39, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 39, 'items': [{'id': '51956d40498e3a08742c24f6', 'createdAt': 1368747328, 'text': 'This is the best Patricias by far, Yeah its a whole in the Wall but the food is amazing', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51956d40498e3a08742c24f6', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '32155226', 'firstName': 'Märlënë', 'lastName': 'Bëltrë', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',  ...
#                          ID        Name  Likes  Rating  Tips
# 0  4b10591af964a5205f6e23e3  Patricia's     84     8.5    39
# ( 5 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0be096d8c56001ba04772'}, 'response': {'venue': {'id': '4acf80aef964a52025d420e3', 'name': "Tino's Delicatessen", 'contact': {'phone': '7187339879', 'formattedPhone': '(718) 733-9879'}, 'location': {'address': '2410 Arthur Ave', 'crossStreet': 'E. 187 St.', 'lat': 40.85588217093613, 'lng': -73.88716612015719, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85588217093613, 'lng': -73.88716612015719}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2410 Arthur Ave (E. 187 St.)', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/tinos-delicatessen/4acf80aef964a52025d420e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d146941735', 'name': 'Deli / Bodega', 'pluralName': 'Delis / Bodegas', 'shortName': 'Deli / Bodega', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d1f9941735', 'name': 'Food & Drink Shop', 'pluralName': 'Food & Drink Shops', 'shortName': 'Food & Drink', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 48}, 'url': 'http://www.tinosdeli.com', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 144, 'groups': [{'type': 'others', 'count': 144, 'items': []}], 'summary': '144 Likes'}, 'dislike': False, 'ok': False, 'rating': 9.1, 'ratingColor': '00B551', 'ratingSignals': 191, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/tinos-delicatessen/4acf80aef964a52025d420e3/menu', 'mobileUrl': 'https://foursquare.com/v/4acf80aef964a52025d420e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 75, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 75, 'items': [{'id': '544818c4498e6354368255e9', 'createdAt': 1414011076, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/89498162_C7BaEoWW6XTbj6MZ_6LI3lBXR6i4EVgpSihEGZk9RO4.jpg', 'width': 640, 'height': 640, 'user': {'id': '89498162', 'firstName': 'LETTUCEDINE', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/89498162-WYUDCZYLMLLJ5ZDJ.jpg'}}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '65699297'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'page': {'user': {'id': '65699297', 'firstName': "Tino's Delicatessen", 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/65699297-1MX1GEJQMZUJLEOL.png'}, 'type': 'venuePage', 'venue': {'id': '4acf80aef964a52025d420e3'}, 'tips': {'count': 2}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'Bronx, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1255112878, 'tips': {'count': 48, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 48, 'items': [{'id': '54b00871498e43e9430459ef', 'createdAt': 1420822641, 'text': "Tino's Deli knows classic heroes, and the $7.95 chicken parm sandwich is the best of the best. Thick Italian bread envelops plump pieces of breaded chicken, all smothered in delectable mozzarella.", 'type': 'user', 'url': 'http://gothamist.com/2014/12/04/best_sandwiches_nyc.php', 'canonicalUrl': 'https://foursquare.com/item/54b00871498e43e9430459ef', 'photo': {'id': '54b00873498e304326a517b5', 'createdAt': 1420822643, 'source': {'n ...
#                          ID                 Name  Likes  Rating  Tips
# 0  4acf80aef964a52025d420e3  Tino's Delicatessen    144     9.1    48
# ( 6 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0bd5802a172001b463e07'}, 'response': {'venue': {'id': '4af71916f964a520cf0522e3', 'name': "Michaelangelo's Coal Fired Brick Oven Pizza Restaurant", 'contact': {'phone': '3475907650', 'formattedPhone': '(347) 590-7650'}, 'location': {'address': '2477 Arthur Ave', 'lat': 40.85741189614754, 'lng': -73.88646821282298, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85741189614754, 'lng': -73.88646821282298}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2477 Arthur Ave', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/michaelangelos-coal-fired-brick-oven-pizza-restaurant/4af71916f964a520cf0522e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 25}, 'url': 'http://michaelangelosbrickoven.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 39, 'groups': [{'type': 'others', 'count': 39, 'items': []}], 'summary': '39 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 63, 'delivery': {'id': '421532', 'url': 'https://www.seamless.com/menu/michaelangelos-2477-arthur-ave-bronx/421532?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=421532', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 50, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 50, 'items': [{'id': '504ff085e4b032bac6b4af9c', 'createdAt': 1347416197, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/6AA2UkeJOIewk3WbcdE2VXJ846RTtkEUUFSpm83S4zc.jpg', 'width': 432, 'height': 720, 'user': {'id': '16166040', 'firstName': 'scattered', 'lastName': 'stanza', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/BJ0ANF5ORNSTSOFG.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1257707798, 'tips': {'count': 25, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 25, 'items': [{'id': '4f2ae186e4b09f4f37d31bf0', 'createdAt': 1328210310, 'text': 'Their calzones are amazing!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4f2ae186e4b09f4f37d31bf0', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '89682827', 'firstName': 'Diana', 'lastName': 'Rodriguez', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/89682827-OJXVNDLLWMUPSW3G.jpg'}}, {'id': '34965840', 'firstName': 'Pascual', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/1MAQY2KRLFL5WU5K.jpg'}}, {'id': '42293572', 'firstName': 'Gabriel', 'lastName': 'J.', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2AKL22HZ00V1A0GF.jpg'}}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'id': '4785374', 'firstName': 'Stephanie', 'lastName': 'Santiago', ' ...
#                          ID  \
# 0  4af71916f964a520cf0522e3
#
#                                                 Name  Likes  Rating  Tips
# 0  Michaelangelo's Coal Fired Brick Oven Pizza Re...     39     8.1    25
# ( 7 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0be0f216785001b694728'}, 'response': {'venue': {'id': '59050f51b23dfa5f6649e678', 'name': 'Arthur Avenue Fiasco', 'contact': {}, 'location': {'address': '2376 Arthur Ave', 'crossStreet': '187th street', 'lat': 40.854844, 'lng': -73.887908, 'labeledLatLngs': [{'label': 'display', 'lat': 40.854844, 'lng': -73.887908}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2376 Arthur Ave (187th street)', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/arthur-avenue-fiasco/59050f51b23dfa5f6649e678', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 9, 'groups': [{'type': 'others', 'count': 9, 'items': [{'id': '11947556', 'firstName': 'Thomas', 'lastName': 'R', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/11947556_8jRPIvSF_YsUHXilYxO5xPDn28TD8QCNs-PQTkhvCZxiGBWvRi6LqnehHb2oDuJVmp6Eei0P5.jpg'}}, {'id': '77062845', 'firstName': 'Mike', 'lastName': 'Higgins', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/77062845-0F21NUVMOX1UOV0U.jpg'}}, {'id': '408008754', 'firstName': 'Elisabeth', 'lastName': 'lopera sanchez', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_girl.png', 'default': True}}, {'id': '76663925', 'firstName': 'Butch', 'lastName': 'Bozzuto', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/76663925-AEY1CHC5XEBI3NRY.jpg'}}]}], 'summary': '9 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 12, 'delivery': {'id': '935894', 'url': 'https://www.seamless.com/menu/arthur-ave-fiasco-2376-arthur-ave-bronx/935894?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=935894', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 9, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 9, 'items': [{'id': '5da29a28d515ae000849c266', 'createdAt': 1570937384, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/34191179_Z3gHBDT3x-8gFEcW12r22rOd-BSPEdtF7_fVD2kjmYs.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '34191179', 'firstName': 'Angela', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/L0HEMDRGZF2FST1D.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1493503825, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '5c97ea2379f6c7002ccc2e46', 'createdAt': 1553459747, 'text': 'Everything is good here!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c97ea2379f6c7002ccc2e46', 'photo': {'id': '5c991e01a8eb60002c0368af', 'createdAt': 1553538561, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/77062845_nm2nnAhhANHai6FP7edZKsGkxyA9bWIkOGMwOzjEdr8.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/77062845_nm2nnAhhANHai6FP7edZKsGkxyA9bWIkOGMwOzjEdr8.jpg', 'lang': 'e ...
#                          ID                  Name  Likes  Rating  Tips
# 0  59050f51b23dfa5f6649e678  Arthur Avenue Fiasco      9     8.1     3
# ( 8 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0bde6963d29001b6980a3'}, 'response': {'venue': {'id': '4bb6470cef159c7465b275f7', 'name': 'Calabria Pork Store', 'contact': {'phone': '7183675145', 'formattedPhone': '(718) 367-5145'}, 'location': {'address': '2338 Arthur Ave', 'lat': 40.85414529023418, 'lng': -73.88877606219484, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85414529023418, 'lng': -73.88877606219484}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2338 Arthur Ave', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/calabria-pork-store/4bb6470cef159c7465b275f7', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1f5941735', 'name': 'Gourmet Shop', 'pluralName': 'Gourmet Shops', 'shortName': 'Gourmet', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 13}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 27, 'groups': [{'type': 'others', 'count': 27, 'items': []}], 'summary': '27 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.8, 'ratingColor': '73CF42', 'ratingSignals': 36, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 54, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 54, 'items': [{'id': '4f773589e4b09a0a539055d9', 'createdAt': 1333212553, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/vX7tJr2Rn4uCYHRFDMMvEoX2lAEGK38qQMdqO1UvQJI.jpg', 'width': 540, 'height': 720, 'user': {'id': '11444295', 'firstName': 'Ed', 'lastName': 'Haddad', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/KKDEGXFIEN1ENW01.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1270236940, 'tips': {'count': 13, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 13, 'items': [{'id': '5192efca498e0bb7e8b1488f', 'createdAt': 1368584138, 'text': "Iconic source for Italian cured meats on the Bronx's Arthur Avenue. Try the wickedly hot soppresata or the spreadable n'duja.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5192efca498e0bb7e8b1488f', 'lang': 'en', 'likes': {'count': 10, 'groups': [{'type': 'others', 'count': 10, 'items': []}], 'summary': '10 likes'}, 'logView': True, 'agreeCount': 10, 'disagreeCount': 0, 'todo': {'count': 8}, 'user': {'id': '12703379', 'firstName': 'Serious Eats', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/12703379-OJSNA253S0GCOKZZ.png'}, 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/bADF6Y', 'timeZone': 'America/New_York', 'listed': {'count': 70, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 70, 'items': [{'id': '4f7bb550e4b09b8aea91ed19', 'name': "T's Foodie Lists: Bronx - Little Italy", 'description': 'Restaurants, bars/speakeasies, bakeries and other goodies!', 'type': 'others', 'user': {'id': '21035948', 'firstName': 'Taline', 'lastName': 'Ekmekjian', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/HG3BFUDG2AL5NDQX.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/21035948/list/ts-foodie-lists-bronx--little-italy', 'canonicalUrl': 'https://foursquare.com/user/21035948/list/ts-foodie-lists-bronx--little-italy', 'createdAt': 1333507408, 'updatedAt': 1386284274, 'photo': {'id': '526193de498eeb85ca5e22e0', 'createdAt': 138212 ...
#                          ID                 Name  Likes  Rating  Tips
# 0  4bb6470cef159c7465b275f7  Calabria Pork Store     27     8.8    13
# ( 9 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0be0914a126001b8f52b1'}, 'response': {'venue': {'id': '4aa425bef964a5208e4520e3', 'name': "Dominick's Restaurant", 'contact': {'phone': '7187332807', 'formattedPhone': '(718) 733-2807', 'twitter': 'dominicksrest'}, 'location': {'address': '2335 Arthur Ave', 'lat': 40.85421506482662, 'lng': -73.88876521498301, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85421506482662, 'lng': -73.88876521498301}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2335 Arthur Ave', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/dominicks-restaurant/4aa425bef964a5208e4520e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 37}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 101, 'groups': [{'type': 'others', 'count': 101, 'items': []}], 'summary': '101 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.4, 'ratingColor': '73CF42', 'ratingSignals': 146, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/dominicks-restaurant/4aa425bef964a5208e4520e3/menu', 'mobileUrl': 'https://foursquare.com/v/4aa425bef964a5208e4520e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 62, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 62, 'items': [{'id': '517c2751e4b0a00475e2095d', 'createdAt': 1367091025, 'source': {'name': 'Foursquare for BlackBerry', 'url': 'https://foursquare.com/download/#/blackberry'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1813734_SyLestXVWcpjWgZkJYTis_oLvMyGnoCWjubaXFAXFfM.jpg', 'width': 641, 'height': 481, 'user': {'id': '1813734', 'firstName': 'Lou', 'lastName': 'Cardillo', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/1813734-MXSUNXZ5NGPKNY5S.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1252271550, 'tips': {'count': 37, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 37, 'items': [{'id': '4f78b5efe4b0d6936a5d0d46', 'createdAt': 1333310959, 'text': 'Stuffed artichoke is awesome.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4f78b5efe4b0d6936a5d0d46', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '41102098', 'firstName': 'Jennifer', 'lastName': 'Gardella', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/U1DR4EBDMKIIUHVJ.jpg'}}, {'id': '901133', 'firstName': 'Patrick', 'lastName': 'D', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/TPBWLLHSPSOTL3MA.jpg'}}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '21914', 'firstName': 'Ari', 'lastName': 'Paparo', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/NEK53IRU5ABXUWDB.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/4ogjrF', 'timeZone': 'America/New_York', 'listed': {'count': 117, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 117, 'items': [{'id': '528116c0498e4f7675e87af8', 'name': 'Cheap Bronx Restaurants', 'description': "Cheapism's editors recommend the best cheap Bronx restaurants on foursquare.\n\nRead more: http://www.cheapism.com/p/cheap-bronx-restaurants.mhtml#ixzz2kvE3Wf9v", 'entities': [{'indices':  ...
#                          ID                   Name  Likes  Rating  Tips
# 0  4aa425bef964a5208e4520e3  Dominick's Restaurant    101     8.4    37
# ( 10 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0be16f7706a001bea827b'}, 'response': {'venue': {'id': '4bc22a22920eb713bcc51b2c', 'name': 'Tra Di Noi', 'contact': {'phone': '7182951784', 'formattedPhone': '(718) 295-1784', 'twitter': 'zeroottonovebrx'}, 'location': {'address': '622 E 187th St', 'lat': 40.855139534007634, 'lng': -73.88679442998631, 'labeledLatLngs': [{'label': 'display', 'lat': 40.855139534007634, 'lng': -73.88679442998631}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['622 E 187th St', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/tra-di-noi/4bc22a22920eb713bcc51b2c', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 13}, 'url': 'http://www.tradinoi.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 44, 'groups': [{'type': 'others', 'count': 44, 'items': []}], 'summary': '44 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.8, 'ratingColor': 'C5DE35', 'ratingSignals': 61, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/tra-di-noi/4bc22a22920eb713bcc51b2c/menu', 'mobileUrl': 'https://foursquare.com/v/4bc22a22920eb713bcc51b2c/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 20, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 20, 'items': [{'id': '5241c72a11d2d084cf1fb5bd', 'createdAt': 1380042538, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/67403_bwJMGw6Ba2UDhR3xhKaHveSSYMrHwnEgFvJLStHRTu8.jpg', 'width': 612, 'height': 612, 'user': {'id': '67403', 'firstName': 'Alan', 'lastName': 'Weinkrantz', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/YLUT4DJ55X43INEQ.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1271015970, 'tips': {'count': 13, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 13, 'items': [{'id': '548f6f2d11d26522d96f42d2', 'createdAt': 1418686253, 'text': 'Their killer lasagna Bolognese is everything you wished mom’s could be. It’s substantial and hearty without being too rich. Don’t sleep on the seafood, either.', 'type': 'user', 'url': 'http://www.thrillist.com/eat/new-york/bronx/best-arthur-ave-restaurants-bars-and-shops-nyc-bronx?utm_source=foursquare&utm_medium=social&utm_campaign=thrillist', 'canonicalUrl': 'https://foursquare.com/item/548f6f2d11d26522d96f42d2', 'photo': {'id': '548f6f6711d2ac75aac85186', 'createdAt': 1418686311, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/268135_M7ZJ5nNd40PYsBAYGTlMeAmXm1yjwk0951Jqcv0Ae60.png', 'width': 737, 'height': 505, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/268135_M7ZJ5nNd40PYsBAYGTlMeAmXm1yjwk0951Jqcv0Ae60.png', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'id': '5673308', 'firstName': 'Victor', 'lastName': 'Hotz Fioreze', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/5673308-T3C2FMLHHQ3440X5.jpg'}}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 1, 'todo': {'count': 2}, 'user': {'id': '268135', 'firstName': 'Thrillist', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', ...
#                          ID        Name  Likes  Rating  Tips
# 0  4bc22a22920eb713bcc51b2c  Tra Di Noi     44     7.8    13
# ( 11 / 237 ) processed
# ...
#                          ID   Name  Likes  Rating  Tips
# 0  5766ad56498ebf269c3737d2  Gersi     76     7.8    15
# ( 47 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0bdfa882fc7001bad29a2'}, 'response': {'venue': {'id': '4a32d7ebf964a520a29a1fe3', 'name': 'Enoteca on Court', 'contact': {'phone': '7182431000', 'formattedPhone': '(718) 243-1000', 'twitter': 'enotecaoncourt1', 'facebook': '100640606612', 'facebookName': 'ENOTECA ON COURT STREET'}, 'location': {'address': '347 Court St', 'crossStreet': 'at Union St.', 'lat': 40.6822145298343, 'lng': -73.99594672669618, 'labeledLatLngs': [{'label': 'display', 'lat': 40.6822145298343, 'lng': -73.99594672669618}], 'postalCode': '11231', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['347 Court St (at Union St.)', 'Brooklyn, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/enoteca-on-court/4a32d7ebf964a520a29a1fe3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d123941735', 'name': 'Wine Bar', 'pluralName': 'Wine Bars', 'shortName': 'Wine Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 27}, 'url': 'http://marcopoloristorante.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 59, 'groups': [{'type': 'others', 'count': 59, 'items': []}], 'summary': '59 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.2, 'ratingColor': 'C5DE35', 'ratingSignals': 97, 'delivery': {'id': '297606', 'url': 'https://www.seamless.com/menu/enoteca-on-court-347-court-st-brooklyn/297606?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=297606', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/enoteca-on-court/4a32d7ebf964a520a29a1fe3/menu', 'mobileUrl': 'https://foursquare.com/v/4a32d7ebf964a520a29a1fe3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 72, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 72, 'items': [{'id': '5a8aefec4816f04619985146', 'createdAt': 1519054828, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/472929014_IsHot8jiSY6ua-pUdAL0UAjD4P90Ir2O2YVNT73PynQ.jpg', 'width': 1500, 'height': 1000, 'user': {'id': '472929014', 'firstName': 'Marco', 'lastName': 'C', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': "Italian comforts, meet innovative tastes. At our shared plate restaurant and wine bar, we're serving chef-driven dishes in a cozy space.", 'page': {'pageInfo': {'links': {'count': 1, 'items': [{'url': 'http://marcopoloristorante.com'}]}}, 'user': {'id': '47230648', 'firstName': 'Marco Polo Corp', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/CN054OHCP3XRXKBV.png'}, 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'Brooklyn, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1244846059, 'tips': {'count': 27, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 27, 'items': [{'id': '53363185498e68b93063510c', 'createdAt': 1396060549, 'text': 'Stick ...
#                          ID              Name  Likes  Rating  Tips
# 0  4a32d7ebf964a520a29a1fe3  Enoteca on Court     59     7.2    27
# ( 48 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0be1df7706a001bea9a0c'}, 'response': {'venue': {'id': '5001e284e4b0d8ae060e1035', 'name': 'Ciros on Smith', 'contact': {}, 'location': {'address': '307 Smith St', 'crossStreet': 'Union', 'lat': 40.68148804379713, 'lng': -73.99402221751436, 'labeledLatLngs': [{'label': 'display', 'lat': 40.68148804379713, 'lng': -73.99402221751436}], 'postalCode': '11231', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['307 Smith St (Union)', 'Brooklyn, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/ciros-on-smith/5001e284e4b0d8ae060e1035', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 5}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': [{'id': '14555927', 'firstName': 'Warren', 'lastName': 'Fraser', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/4W5GOU1Y3IXKROTG.jpg'}}, {'id': '37', 'firstName': 'Alex', 'lastName': 'Rainert', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2BEJLERMRPQ24MDT.jpg'}}, {'id': '8561', 'firstName': 'Clay', 'lastName': 'Wiedemann', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/8561_JrngBkdU_E9mzgTAAWopweW3XPWIlIo3dvlvZDl6Eu2qzU0BzM4oGMckRiMaVMKiJOYdLr1df.jpg'}}, {'id': '5467074', 'firstName': 'Matthew', 'lastName': 'Sheppard', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/0UEMNIMJ3P5P1DWT.jpg'}}]}], 'summary': '8 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.8, 'ratingColor': 'FFC800', 'ratingSignals': 12, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/ciros-on-smith/5001e284e4b0d8ae060e1035/menu', 'mobileUrl': 'https://foursquare.com/v/5001e284e4b0d8ae060e1035/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 5, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 5, 'items': [{'id': '51d3783b498ee56d078d96b3', 'createdAt': 1372813371, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/40322128_ZXjfWOXUOjh7jFCwnH41xMhhr-BkG3iZsZIfUNudnuE.jpg', 'width': 612, 'height': 612, 'user': {'id': '40322128', 'firstName': 'Sevan', 'lastName': 'Gatsby', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/4N3MAVQMYNNVLM5J.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1342300804, 'tips': {'count': 5, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 5, 'items': [{'id': '51ce2d53222f46ef10dcc28e', 'createdAt': 1372466515, 'text': "The food is like your little Italian best friend's grandmama would make for you. Strong, classic, rustic dishes. Tuscan Kale salad, arancini (rice balls) and spaghetti & meatballs all slayed.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51ce2d53222f46ef10dcc28e', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'id': '15629', 'firstName': 'Paul', 'lastName': 'Steketee', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/BVSZCXZUKL2NUDWM.jpg'}}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '37', 'firstName': 'Alex', 'lastName': 'Rainert', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.ne ...
#                          ID            Name  Likes  Rating  Tips
# 0  5001e284e4b0d8ae060e1035  Ciros on Smith      8     6.8     5
# ( 49 / 237 ) processed
# {'meta': {'code': 200, 'requestId': '5de0bdee963d29001b699a29'}, 'response': {'venue': {'id': '4ab98ab8f964a520cf7f20e3', 'name': 'Marco Polo Ristorante', 'contact': {'phone': '7188525015', 'formattedPhone': '(718) 852-5015', 'twitter': 'marcopolorist'}, 'location': {'address': '345 Court St', 'crossStreet': 'at Union St', 'lat': 40.68231096732147, 'lng': -73.99591141723491, 'labeledLatLngs': [{'label': 'display', 'lat': 40.68231096732147, 'lng': -73.99591141723491}], 'postalCode': '11231', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['345 Court St (at Union St)', 'Brooklyn, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/marco-polo-ristorante/4ab98ab8f964a520cf7f20e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 14}, 'url': 'http://marcopoloristorante.com', 'price': {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 32, 'groups': [{'type': 'others', 'count': 32, 'items': []}], 'summary': '32 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.6, 'ratingColor': 'FFC800', 'ratingSignals': 55, 'delivery': {'id': '556391', 'url': 'https://www.seamless.com/menu/marco-polo-ristorante-345-court-st-brooklyn/556391?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=556391', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/marco-polo-ristorante/4ab98ab8f964a520cf7f20e3/menu', 'mobileUrl': 'https://foursquare.com/v/4ab98ab8f964a520cf7f20e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 56, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 56, 'items': [{'id': '51bcf77d498e8e4e6918fd4c', 'createdAt': 1371338621, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/18735538_7S92Y8RL2lFgvDkC4HrgFMkSmzKnJJiZ7sZmKlejuLQ.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '18735538', 'firstName': 'Jessica', 'lastName': 'Baird', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/18735538-3AUAIZN0CJJ3Q1KJ.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Bringing together good taste, good times, and good people since 1983. Join us for authentic Italian eats and an impeccable happy hour.', 'page': {'pageInfo': {'links': {'count': 1, 'items': [{'url': 'http://marcopoloristorante.com'}]}}, 'user': {'id': '47230648', 'firstName': 'Marco Polo Corp', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/CN054OHCP3XRXKBV.png'}, 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'Brooklyn, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1253673656, 'tips': {'count': 14, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 14, 'items': [{'id': '4ff8d3eee4b083d14ceb2f33', 'createdAt': 1341707246, 'text': 'Start with 48 oysters & a bottle of champagne and end with the chocolate cake. Ask the live pianist to sing your fave Sinatra song. This spot, my friends, is Old School Brooklyn Italian.', 'type': 'user', 'canonicalUrl': 'https: ...
#                          ID                   Name  Likes  Rating  Tips
# 0  4ab98ab8f964a520cf7f20e3  Marco Polo Ristorante     32     6.6    14
# ( 50 / 237 ) processed
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5de0bd96aba297001b967778'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-45286ff00219> in <module>
#       5     Borough,Neighborhood,ID,Name=row
#       6     try:
# ----> 7         venue_details=get_venue_details(ID)
#       8         print(venue_details)
#       9         id,name,likes,rating,tips=venue_details.values.tolist()[0]
#
# <ipython-input-3-97a8e3201e67> in get_venue_details(venue_id)
#      48     results = requests.get(url).json()
#      49     print(results)
# ---> 50     venue_data=results['response']['venue']
#      51     venue_details=[]
#      52     try:
#
# KeyError: 'venue'

# %%
italian_rest_stats_ny.to_csv('italian_rest_stats_ny_csv.csv')

# %%
italian_rest_stats_ny['Likes']=italian_rest_stats_ny['Likes'].astype('float64')
italian_rest_stats_ny['Tips']=italian_rest_stats_ny['Tips'].astype('float64')
# Resturant with maximum Likes
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Likes'].idxmax()]
# Out:
# Borough                            Bronx
# Neighborhood                     Belmont
# ID              4acf80aef964a52025d420e3
# Name                 Tino's Delicatessen
# Likes                                144
# Rating                               9.1
# Tips                                  48
# Name: 5, dtype: object

# %%
# Resturant with maximum Ratings
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Rating'].idxmax()]
# Out:
# Borough                         Brooklyn
# Neighborhood                    Bushwick
# ID              5a98aed16a59506d7a60d67c
# Name                          Carmenta’s
# Likes                                 50
# Rating                               9.3
# Tips                                  21
# Name: 39, dtype: object

# %%
# Resturant with maximum Tips
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Tips'].idxmax()]
# Out:
# Borough                            Bronx
# Neighborhood                     Belmont
# ID              4acf80aef964a52025d420e3
# Name                 Tino's Delicatessen
# Likes                                144
# Rating                               9.1
# Tips                                  48
# Name: 5, dtype: object

# %%
ny_neighborhood_stats=italian_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#       Neighborhood  Average Rating
# 3         Bushwick        9.300000
# 11     Morris Park        8.500000
# 14  Pelham Gardens        8.400000
# 17        Woodlawn        8.300000
# 6      Cobble Hill        8.300000
# 5      City Island        8.100000
# 10      Greenpoint        8.000000
# 1          Belmont        7.870588
# 13      Pelham Bay        7.750000
# 9        Gravesend        7.700000

# %%
ny_borough_stats=italian_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#     Borough  Average Rating
# 0     Bronx        7.803571
# 1  Brooklyn        7.254545

# %%
italian_rest_stats_ny.groupby('Borough').mean()['Rating'].plot.bar(figsize=(10,5), color='green')
plt.title('Average rating of Italian Resturants for each Borough', fontsize=20)
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('Average Rating', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=8.0]
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,ny_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
# create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ny_neighborhood_stats
# Out:
#     Borough    Neighborhood   Latitude  Longitude  Average Rating  \
# 0  Brooklyn        Bushwick  40.698116 -73.925258             9.3
# 1     Bronx     City Island  40.847247 -73.786488             8.1
# 2  Brooklyn     Cobble Hill  40.687920 -73.998561             8.3
# 3  Brooklyn      Greenpoint  40.730201 -73.954241             8.0
# 4     Bronx     Morris Park  40.847549 -73.850402             8.5
# 5     Bronx  Pelham Gardens  40.862966 -73.841612             8.4
# 6     Bronx        Woodlawn  40.898273 -73.867315             8.3
#
#                                       Label
# 0                   Bushwick, Brooklyn(9.3)
# 1                   City Island, Bronx(8.1)
# 2  Cobble Hill, Brooklyn(8.299999999999999)
# 3                 Greenpoint, Brooklyn(8.0)
# 4                   Morris Park, Bronx(8.5)
# 5                Pelham Gardens, Bronx(8.4)
# 6                      Woodlawn, Bronx(8.3)

# %% [markdown]
# ## Results / Conclusion
# Manhattan and Queens have the best rated Italian restaurants on average. Queens and The Bronx have the least amount of Italian restaurants per borough. However, of note, Belmont of The Bronx is the neighborhood in all of NYC with the most Italian Restaurants. Despite Manhattan having the least number of neighborhoods in all five boroughs, it has the most Italian restaurants. Based on this information, I would state that Manhattan and Queens are the best locations for Italian cuisine in NYC. To have the best shot of success, I would open an Italian restaurants in Queens. Queens has multiple neighborhoods with average ratings exceeding 8.0 of a scale of 1.0 to 10.0 and has the least number of Italian restaurants making competition easier than in other boroughs. Finally, I would go to Gramercy in Manhattan for the best Italian food based on 131 likes. As a final note, all of the above analysis is depended on the adequacy and accuracy of Four Square data. A more comprehensive analysis and future work would need to incorporate data from other external databases
